# %% [markdown]
# Image Detection Model Building

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
x_train = train_datagen.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/Iceberg Detection/dataset/train",target_size=(75,75),batch_size= 32, class_mode='binary')
x_test = test_datagen.flow_from_directory("/content/drive/MyDrive/Colab Notebooks/Iceberg Detection/dataset/test",target_size=(75,75),batch_size= 32, class_mode='binary')
# Out:
# Found 710 images belonging to 2 classes.
# Found 192 images belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten

# %%
model = Sequential()

# %%
model.add(Conv2D(64,(3,3), activation='relu', input_shape=(75,75,3)))

# %%
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(units= 512, kernel_initializer="uniform", activation="relu"))
model.add(Dense(units = 256, kernel_initializer="uniform", activation="relu"))
model.add(Dense(units = 1, kernel_initializer="uniform", activation="sigmoid"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit_generator(x_train,steps_per_epoch=22, epochs= 10, validation_data=x_test, validation_steps=20)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# ...
# 22/22 [==============================] - 14s 627ms/step - loss: 0.3517 - accuracy: 0.8555 - val_loss: 0.5731 - val_accuracy: 0.7500
# Epoch 2/10
# 22/22 [==============================] - 12s 552ms/step - loss: 0.3362 - accuracy: 0.8363
# Epoch 3/10
# 22/22 [==============================] - 12s 556ms/step - loss: 0.2942 - accuracy: 0.8776
# Epoch 4/10
# 22/22 [==============================] - 12s 548ms/step - loss: 0.3264 - accuracy: 0.8687
# Epoch 5/10
# 22/22 [==============================] - 12s 546ms/step - loss: 0.3204 - accuracy: 0.8643
# Epoch 6/10
# 22/22 [==============================] - 12s 547ms/step - loss: 0.3269 - accuracy: 0.8643
# Epoch 7/10
# ...

# %%
x_train.class_indices
# Out:
# {'Iceberg': 0, 'Ship': 1}

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/iceberg_model.h5")
